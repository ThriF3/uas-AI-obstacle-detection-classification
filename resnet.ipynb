# %% [markdown]
# Reference: **[Residual Networks (ResNet) - Deep Learning](https://www.geeksforgeeks.org/deep-learning/residual-networks-resnet-deep-learning/)**
#
# Modified by the help of ChatGPT

# %% [markdown]
# ## 1. Importing keras APIs and modules.
# These APIs help in building the architecture of the ResNet Module

# %%
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
import numpy as np
import os
import json
from pathlib import Path
import cv2
from sklearn.preprocessing import LabelEncoder
# Out:
# Failed to start the Kernel.
#
# The kernel died. Error: ... View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## 2. Hyper parameters and pre-processing

# %%
batch_size = 32
epochs = 200
data_augmentation = True
subtract_pixel_mean = True
n = 3
version = 1

if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

model_type = 'ResNet % dv % d' % (depth, version)

# Load COCO annotations
dataset_path = Path('dashcam 2.v1i.coco/train')
annotations_file = dataset_path / '_annotations.coco.json'

with open(annotations_file, 'r') as f:
    coco_data = json.load(f)

# Parse COCO format
images_info = {img['id']: img for img in coco_data['images']}
categories = {cat['id']: cat['name'] for cat in coco_data['categories']}

# Load images and annotations
x_train = []
y_train = []

for annotation in coco_data['annotations']:
    img_id = annotation['image_id']
    img_info = images_info[img_id]
    img_path = dataset_path / img_info['file_name']
    
    # Read and preprocess image
    img = cv2.imread(str(img_path))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (32, 32))  # Resize to match CIFAR-10 size
    x_train.append(img)
    
    # Get category label
    category_id = annotation['category_id']
    category_name = categories[category_id]
    y_train.append(category_name)

x_train = np.array(x_train, dtype='float32') / 255
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train).reshape(-1, 1)

num_classes = len(label_encoder.classes_)

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print('y_train shape:', y_train.shape)
print('Classes:', label_encoder.classes_)
# Out:
# x_train shape: (5631, 32, 32, 3)
# 5631 train samples
# y_train shape: (5631, 1)
# Classes: ['Mobil' 'Motor' 'Orang' 'Truk']

# %% [markdown]
# ## 3. Learning Rate Schedule
# Used to adjust learning rate based on the amount of epochs.

# %%
def lr_schedule(epoch):
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %% [markdown]
# ## 4. Basic ResNet Building Block

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %% [markdown]
# ## 5. Defining ResNet Architecture

# %%
def resnet_v1(input_shape, depth, num_classes=10): 
    if (depth - 2) % 6 != 0: 
        raise ValueError('depth should be 6n + 2 (eg 20, 32, 44 in [a])') 

    num_filters = 16
    num_res_blocks = int((depth - 2) / 6) 

    inputs = Input(shape=input_shape) 
    x = resnet_layer(inputs=inputs) 

    for stack in range(3): 
        for res_block in range(num_res_blocks): 
            strides = 1
            if stack > 0 and res_block == 0: 
                strides = 2 
            y = resnet_layer(inputs=x, 
                             num_filters=num_filters, 
                             strides=strides) 
            y = resnet_layer(inputs=y, 
                             num_filters=num_filters, 
                             activation=None) 
            if stack > 0 and res_block == 0: 
                x = resnet_layer(inputs=x, 
                                 num_filters=num_filters, 
                                 kernel_size=1, 
                                 strides=strides, 
                                 activation=None, 
                                 batch_normalization=False) 
            x = keras.layers.add([x, y]) 
            x = Activation('relu')(x) 
        num_filters *= 2

    x = AveragePooling2D(pool_size=8)(x) 
    y = Flatten()(x) 
    outputs = Dense(num_classes, 
                    activation='softmax', 
                    kernel_initializer='he_normal')(y) 

    model = Model(inputs=inputs, outputs=outputs) 
    return model

# %% [markdown]
# ## 6. Train and test the model

# %%
model = resnet_v1(input_shape=x_train.shape[1:], depth=depth, num_classes=num_classes)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
print(model_type)

save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.keras' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

checkpoint = ModelCheckpoint(filepath=filepath,
                              monitor='val_acc',
                              verbose=1,
                              mode='max',
                              save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=10,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, keras.utils.to_categorical(y_train, num_classes),
              batch_size=batch_size,
              epochs=epochs,
              validation_split=0.2,
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # Complete the ImageDataGenerator
    datagen = ImageDataGenerator(
        featurewise_center=False,
        samplewise_center=False,
        zca_whitening=False,
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest'
    )
    
    # Fit the generator on the training data
    datagen.fit(x_train)

    # Convert labels to categorical
    y_train_cat = keras.utils.to_categorical(y_train, num_classes)
    
    # Split data into train and validation sets manually
    split_idx = int(0.8 * len(x_train))
    x_train_split = x_train[:split_idx]
    y_train_split = y_train_cat[:split_idx]
    x_val = x_train[split_idx:]
    y_val = y_train_cat[split_idx:]

    # Use the generator for training
    model.fit(datagen.flow(x_train_split, y_train_split, batch_size=batch_size),
              steps_per_epoch=x_train_split.shape[0] // batch_size,
              epochs=epochs,
              validation_data=(x_val, y_val),
              callbacks=callbacks)
# Out:
# Learning rate:  0.001
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 32, 32, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 32, 32,    │        448 │ input_layer_2[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_42[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_38       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 32, 32,    │      2,320 │ activation_38[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_43[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_39       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 32, 32,    │      2,320 │ activation_39[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_44[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_18 (Add)        │ (None, 32, 32,    │          0 │ activation_38[0]… │
# │                     │ 16)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_40       │ (None, 32, 32,    │          0 │ add_18[0][0]      │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (None, 32, 32,    │      2,320 │ activation_40[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_45[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_41       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_46 (Conv2D)  │ (None, 32, 32,    │      2,320 │ activation_41[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_46[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_19 (Add)        │ (None, 32, 32,    │          0 │ activation_40[0]… │
# │                     │ 16)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_42       │ (None, 32, 32,    │          0 │ add_19[0][0]      │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_47 (Conv2D)  │ (None, 32, 32,    │      2,320 │ activation_42[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_47[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_43       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_48 (Conv2D)  │ (None, 32, 32,    │      2,320 │ activation_43[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_48[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_20 (Add)        │ (None, 32, 32,    │          0 │ activation_42[0]… │
# │                     │ 16)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_44       │ (None, 32, 32,    │          0 │ add_20[0][0]      │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_49 (Conv2D)  │ (None, 16, 16,    │      4,640 │ activation_44[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_49[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_45       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_50 (Conv2D)  │ (None, 16, 16,    │      9,248 │ activation_45[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_51 (Conv2D)  │ (None, 16, 16,    │        544 │ activation_44[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_50[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_21 (Add)        │ (None, 16, 16,    │          0 │ conv2d_51[0][0],  │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_46       │ (None, 16, 16,    │          0 │ add_21[0][0]      │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_52 (Conv2D)  │ (None, 16, 16,    │      9,248 │ activation_46[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_52[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_47       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_53 (Conv2D)  │ (None, 16, 16,    │      9,248 │ activation_47[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_53[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_22 (Add)        │ (None, 16, 16,    │          0 │ activation_46[0]… │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_48       │ (None, 16, 16,    │          0 │ add_22[0][0]      │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_54 (Conv2D)  │ (None, 16, 16,    │      9,248 │ activation_48[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_54[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_49       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_55 (Conv2D)  │ (None, 16, 16,    │      9,248 │ activation_49[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_55[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_23 (Add)        │ (None, 16, 16,    │          0 │ activation_48[0]… │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_50       │ (None, 16, 16,    │          0 │ add_23[0][0]      │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_56 (Conv2D)  │ (None, 8, 8, 64)  │     18,496 │ activation_50[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_56[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_51       │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_57 (Conv2D)  │ (None, 8, 8, 64)  │     36,928 │ activation_51[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_58 (Conv2D)  │ (None, 8, 8, 64)  │      2,112 │ activation_50[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_57[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_24 (Add)        │ (None, 8, 8, 64)  │          0 │ conv2d_58[0][0],  │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_52       │ (None, 8, 8, 64)  │          0 │ add_24[0][0]      │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_59 (Conv2D)  │ (None, 8, 8, 64)  │     36,928 │ activation_52[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_59[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_53       │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_60 (Conv2D)  │ (None, 8, 8, 64)  │     36,928 │ activation_53[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_60[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_25 (Add)        │ (None, 8, 8, 64)  │          0 │ activation_52[0]… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_54       │ (None, 8, 8, 64)  │          0 │ add_25[0][0]      │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_61 (Conv2D)  │ (None, 8, 8, 64)  │     36,928 │ activation_54[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_61[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_55       │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_62 (Conv2D)  │ (None, 8, 8, 64)  │     36,928 │ activation_55[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_62[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_26 (Add)        │ (None, 8, 8, 64)  │          0 │ activation_54[0]… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_56       │ (None, 8, 8, 64)  │          0 │ add_26[0][0]      │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_2 │ (None, 1, 1, 64)  │          0 │ activation_56[0]… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_2 (Flatten) │ (None, 64)        │          0 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 4)         │        260 │ flatten_2[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 274,052 (1.05 MB)
#  Trainable params: 272,676 (1.04 MB)
#  Non-trainable params: 1,376 (5.38 KB)
# ResNet  20v  1
# Using real-time data augmentation.
# Learning rate:  0.001
# Epoch 1/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.3389 - loss: 1.5838
# e:\pyenv\.comvis\Lib\site-packages\keras\src\callbacks\model_checkpoint.py:276: UserWarning: Can save best model only with val_acc available.
#   if self._should_save_model(epoch, batch, logs, filepath):
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 21s 81ms/step - accuracy: 0.3853 - loss: 1.4713 - val_accuracy: 0.4046 - val_loss: 1.4192 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 2/200
# Learning rate:  0.001
# Epoch 2/200
#   1/140 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - accuracy: 0.4375 - loss: 1.4324
# e:\pyenv\.comvis\Lib\site-packages\keras\src\trainers\epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4375 - loss: 1.4324 - val_accuracy: 0.3931 - val_loss: 1.4399 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 3/200
# Learning rate:  0.001
# Epoch 3/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step - accuracy: 0.4725 - loss: 1.3231 - val_accuracy: 0.4969 - val_loss: 1.3354 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 4/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step - accuracy: 0.4725 - loss: 1.3231 - val_accuracy: 0.4969 - val_loss: 1.3354 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 4/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6250 - loss: 1.0910 - val_accuracy: 0.4880 - val_loss: 1.3305 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 5/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6250 - loss: 1.0910 - val_accuracy: 0.4880 - val_loss: 1.3305 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 5/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 77ms/step - accuracy: 0.5076 - loss: 1.2627 - val_accuracy: 0.5324 - val_loss: 1.2373 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 6/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 77ms/step - accuracy: 0.5076 - loss: 1.2627 - val_accuracy: 0.5324 - val_loss: 1.2373 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 6/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5938 - loss: 1.2732 - val_accuracy: 0.5386 - val_loss: 1.2284 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 7/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5938 - loss: 1.2732 - val_accuracy: 0.5386 - val_loss: 1.2284 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 7/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - accuracy: 0.5501 - loss: 1.2006 - val_accuracy: 0.3913 - val_loss: 2.0507 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 8/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - accuracy: 0.5501 - loss: 1.2006 - val_accuracy: 0.3913 - val_loss: 2.0507 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 8/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5000 - loss: 1.2114 - val_accuracy: 0.4179 - val_loss: 1.9632 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 9/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5000 - loss: 1.2114 - val_accuracy: 0.4179 - val_loss: 1.9632 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 9/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.5510 - loss: 1.1730 - val_accuracy: 0.4951 - val_loss: 1.3359 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 10/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.5510 - loss: 1.1730 - val_accuracy: 0.4951 - val_loss: 1.3359 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 10/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5938 - loss: 1.0186 - val_accuracy: 0.5031 - val_loss: 1.3480 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 11/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5938 - loss: 1.0186 - val_accuracy: 0.5031 - val_loss: 1.3480 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 11/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.5733 - loss: 1.1248 - val_accuracy: 0.5102 - val_loss: 1.4390 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 12/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.5733 - loss: 1.1248 - val_accuracy: 0.5102 - val_loss: 1.4390 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 12/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7188 - loss: 1.0255 - val_accuracy: 0.5155 - val_loss: 1.4030 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 13/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7188 - loss: 1.0255 - val_accuracy: 0.5155 - val_loss: 1.4030 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 13/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step - accuracy: 0.5716 - loss: 1.1185 - val_accuracy: 0.5350 - val_loss: 1.3454 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 14/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step - accuracy: 0.5716 - loss: 1.1185 - val_accuracy: 0.5350 - val_loss: 1.3454 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 14/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5625 - loss: 1.1461 - val_accuracy: 0.5466 - val_loss: 1.3505 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 15/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5625 - loss: 1.1461 - val_accuracy: 0.5466 - val_loss: 1.3505 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 15/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 81ms/step - accuracy: 0.6047 - loss: 1.0798 - val_accuracy: 0.5013 - val_loss: 1.6133 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 16/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 81ms/step - accuracy: 0.6047 - loss: 1.0798 - val_accuracy: 0.5013 - val_loss: 1.6133 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 16/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5625 - loss: 1.0431 - val_accuracy: 0.4596 - val_loss: 1.7638 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 17/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5625 - loss: 1.0431 - val_accuracy: 0.4596 - val_loss: 1.7638 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 17/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.6091 - loss: 1.0532 - val_accuracy: 0.4827 - val_loss: 1.2748 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 18/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.6091 - loss: 1.0532 - val_accuracy: 0.4827 - val_loss: 1.2748 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 18/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6875 - loss: 0.9028 - val_accuracy: 0.5013 - val_loss: 1.2545 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 19/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6875 - loss: 0.9028 - val_accuracy: 0.5013 - val_loss: 1.2545 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 19/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - accuracy: 0.6286 - loss: 1.0308 - val_accuracy: 0.5537 - val_loss: 1.2909 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 20/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - accuracy: 0.6286 - loss: 1.0308 - val_accuracy: 0.5537 - val_loss: 1.2909 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 20/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7812 - loss: 0.8424 - val_accuracy: 0.5501 - val_loss: 1.3236 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 21/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7812 - loss: 0.8424 - val_accuracy: 0.5501 - val_loss: 1.3236 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 21/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.6237 - loss: 1.0236 - val_accuracy: 0.5759 - val_loss: 1.4008 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 22/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.6237 - loss: 1.0236 - val_accuracy: 0.5759 - val_loss: 1.4008 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 22/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7500 - loss: 0.7592 - val_accuracy: 0.5705 - val_loss: 1.3489 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 23/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7500 - loss: 0.7592 - val_accuracy: 0.5705 - val_loss: 1.3489 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 23/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.6284 - loss: 1.0081 - val_accuracy: 0.5200 - val_loss: 1.7082 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 24/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.6284 - loss: 1.0081 - val_accuracy: 0.5200 - val_loss: 1.7082 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 24/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5625 - loss: 1.1075 - val_accuracy: 0.5200 - val_loss: 1.5392 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 25/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5625 - loss: 1.1075 - val_accuracy: 0.5200 - val_loss: 1.5392 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 25/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.6398 - loss: 0.9783 - val_accuracy: 0.3718 - val_loss: 3.1068 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 26/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.6398 - loss: 0.9783 - val_accuracy: 0.3718 - val_loss: 3.1068 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 26/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6875 - loss: 0.8379 - val_accuracy: 0.3691 - val_loss: 3.0735 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 27/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6875 - loss: 0.8379 - val_accuracy: 0.3691 - val_loss: 3.0735 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 27/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.6469 - loss: 0.9542 - val_accuracy: 0.5466 - val_loss: 1.4771 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 28/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.6469 - loss: 0.9542 - val_accuracy: 0.5466 - val_loss: 1.4771 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 28/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7500 - loss: 0.8313 - val_accuracy: 0.5492 - val_loss: 1.5258 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 29/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7500 - loss: 0.8313 - val_accuracy: 0.5492 - val_loss: 1.5258 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 29/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step - accuracy: 0.6559 - loss: 0.9434 - val_accuracy: 0.5528 - val_loss: 1.3515 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 30/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step - accuracy: 0.6559 - loss: 0.9434 - val_accuracy: 0.5528 - val_loss: 1.3515 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 30/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5000 - loss: 1.2358 - val_accuracy: 0.5457 - val_loss: 1.3252 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 31/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5000 - loss: 1.2358 - val_accuracy: 0.5457 - val_loss: 1.3252 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 31/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.6664 - loss: 0.9299 - val_accuracy: 0.5421 - val_loss: 1.3271 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 32/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.6664 - loss: 0.9299 - val_accuracy: 0.5421 - val_loss: 1.3271 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 32/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6875 - loss: 1.0477 - val_accuracy: 0.5581 - val_loss: 1.3034 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 33/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6875 - loss: 1.0477 - val_accuracy: 0.5581 - val_loss: 1.3034 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 33/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.6670 - loss: 0.9247 - val_accuracy: 0.5812 - val_loss: 1.2045 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 34/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.6670 - loss: 0.9247 - val_accuracy: 0.5812 - val_loss: 1.2045 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 34/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7812 - loss: 0.8412 - val_accuracy: 0.5909 - val_loss: 1.1724 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 35/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7812 - loss: 0.8412 - val_accuracy: 0.5909 - val_loss: 1.1724 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 35/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.6711 - loss: 0.9241 - val_accuracy: 0.5679 - val_loss: 1.2589 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 36/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.6711 - loss: 0.9241 - val_accuracy: 0.5679 - val_loss: 1.2589 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 36/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6562 - loss: 0.8250 - val_accuracy: 0.5617 - val_loss: 1.2813 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 37/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6562 - loss: 0.8250 - val_accuracy: 0.5617 - val_loss: 1.2813 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 37/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.6791 - loss: 0.9053 - val_accuracy: 0.5120 - val_loss: 1.9059 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 38/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.6791 - loss: 0.9053 - val_accuracy: 0.5120 - val_loss: 1.9059 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 38/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7500 - loss: 0.9126 - val_accuracy: 0.5146 - val_loss: 1.8980 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 39/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7500 - loss: 0.9126 - val_accuracy: 0.5146 - val_loss: 1.8980 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 39/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.6818 - loss: 0.8989 - val_accuracy: 0.5847 - val_loss: 1.2379 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 40/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.6818 - loss: 0.8989 - val_accuracy: 0.5847 - val_loss: 1.2379 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 40/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5938 - loss: 0.9682 - val_accuracy: 0.5830 - val_loss: 1.2197 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 41/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5938 - loss: 0.9682 - val_accuracy: 0.5830 - val_loss: 1.2197 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 41/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 72ms/step - accuracy: 0.6853 - loss: 0.8852 - val_accuracy: 0.5714 - val_loss: 1.4646 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 42/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 72ms/step - accuracy: 0.6853 - loss: 0.8852 - val_accuracy: 0.5714 - val_loss: 1.4646 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 42/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6250 - loss: 0.9629 - val_accuracy: 0.5634 - val_loss: 1.4425 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 43/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6250 - loss: 0.9629 - val_accuracy: 0.5634 - val_loss: 1.4425 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 43/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.6767 - loss: 0.8866 - val_accuracy: 0.6291 - val_loss: 1.2041 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 44/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.6767 - loss: 0.8866 - val_accuracy: 0.6291 - val_loss: 1.2041 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 44/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7500 - loss: 0.6523 - val_accuracy: 0.6114 - val_loss: 1.2105 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 45/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7500 - loss: 0.6523 - val_accuracy: 0.6114 - val_loss: 1.2105 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 45/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.6883 - loss: 0.8686 - val_accuracy: 0.5785 - val_loss: 1.3692 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 46/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.6883 - loss: 0.8686 - val_accuracy: 0.5785 - val_loss: 1.3692 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 46/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6875 - loss: 0.7544 - val_accuracy: 0.5794 - val_loss: 1.3905 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 47/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6875 - loss: 0.7544 - val_accuracy: 0.5794 - val_loss: 1.3905 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 47/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.6901 - loss: 0.8665 - val_accuracy: 0.6442 - val_loss: 1.1806 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 48/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.6901 - loss: 0.8665 - val_accuracy: 0.6442 - val_loss: 1.1806 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 48/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6875 - loss: 0.7458 - val_accuracy: 0.6398 - val_loss: 1.1977 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 49/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6875 - loss: 0.7458 - val_accuracy: 0.6398 - val_loss: 1.1977 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 49/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.6874 - loss: 0.8595 - val_accuracy: 0.4055 - val_loss: 4.2927 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 50/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.6874 - loss: 0.8595 - val_accuracy: 0.4055 - val_loss: 4.2927 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 50/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6562 - loss: 0.8788 - val_accuracy: 0.4135 - val_loss: 3.9923 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 51/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6562 - loss: 0.8788 - val_accuracy: 0.4135 - val_loss: 3.9923 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 51/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.6892 - loss: 0.8553 - val_accuracy: 0.5617 - val_loss: 1.3421 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 52/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.6892 - loss: 0.8553 - val_accuracy: 0.5617 - val_loss: 1.3421 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 52/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7500 - loss: 0.8181 - val_accuracy: 0.5572 - val_loss: 1.3581 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 53/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7500 - loss: 0.8181 - val_accuracy: 0.5572 - val_loss: 1.3581 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 53/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.6907 - loss: 0.8595 - val_accuracy: 0.5359 - val_loss: 1.4923 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 54/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.6907 - loss: 0.8595 - val_accuracy: 0.5359 - val_loss: 1.4923 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 54/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7500 - loss: 0.9996 - val_accuracy: 0.5448 - val_loss: 1.4862 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 55/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7500 - loss: 0.9996 - val_accuracy: 0.5448 - val_loss: 1.4862 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 55/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.7019 - loss: 0.8389 - val_accuracy: 0.5954 - val_loss: 1.3632 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 56/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.7019 - loss: 0.8389 - val_accuracy: 0.5954 - val_loss: 1.3632 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 56/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6562 - loss: 0.8840 - val_accuracy: 0.5865 - val_loss: 1.3462 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 57/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6562 - loss: 0.8840 - val_accuracy: 0.5865 - val_loss: 1.3462 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 57/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.7124 - loss: 0.8250 - val_accuracy: 0.5918 - val_loss: 1.3261 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 58/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.7124 - loss: 0.8250 - val_accuracy: 0.5918 - val_loss: 1.3261 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 58/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5938 - loss: 1.0103 - val_accuracy: 0.6007 - val_loss: 1.2577 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 59/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5938 - loss: 1.0103 - val_accuracy: 0.6007 - val_loss: 1.2577 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 59/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.7004 - loss: 0.8383 - val_accuracy: 0.6202 - val_loss: 1.1889 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 60/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.7004 - loss: 0.8383 - val_accuracy: 0.6202 - val_loss: 1.1889 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 60/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7188 - loss: 0.7516 - val_accuracy: 0.6211 - val_loss: 1.1569 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 61/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7188 - loss: 0.7516 - val_accuracy: 0.6211 - val_loss: 1.1569 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 61/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.7102 - loss: 0.8140 - val_accuracy: 0.5138 - val_loss: 1.4580 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 62/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.7102 - loss: 0.8140 - val_accuracy: 0.5138 - val_loss: 1.4580 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 62/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6875 - loss: 0.6878 - val_accuracy: 0.5200 - val_loss: 1.4791 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 63/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6875 - loss: 0.6878 - val_accuracy: 0.5200 - val_loss: 1.4791 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 63/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.7100 - loss: 0.8086 - val_accuracy: 0.5244 - val_loss: 1.5216 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 64/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.7100 - loss: 0.8086 - val_accuracy: 0.5244 - val_loss: 1.5216 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 64/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7500 - loss: 0.7637 - val_accuracy: 0.5288 - val_loss: 1.5356 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 65/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7500 - loss: 0.7637 - val_accuracy: 0.5288 - val_loss: 1.5356 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 65/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.7068 - loss: 0.8082 - val_accuracy: 0.5244 - val_loss: 2.0571 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 66/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.7068 - loss: 0.8082 - val_accuracy: 0.5244 - val_loss: 2.0571 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 66/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5312 - loss: 0.9730 - val_accuracy: 0.5297 - val_loss: 1.9706 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 67/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5312 - loss: 0.9730 - val_accuracy: 0.5297 - val_loss: 1.9706 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 67/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.7142 - loss: 0.7961 - val_accuracy: 0.6078 - val_loss: 1.1790 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 68/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.7142 - loss: 0.7961 - val_accuracy: 0.6078 - val_loss: 1.1790 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 68/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7188 - loss: 0.9539 - val_accuracy: 0.6051 - val_loss: 1.1855 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 69/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7188 - loss: 0.9539 - val_accuracy: 0.6051 - val_loss: 1.1855 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 69/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.7129 - loss: 0.8077 - val_accuracy: 0.5643 - val_loss: 1.3484 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 70/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.7129 - loss: 0.8077 - val_accuracy: 0.5643 - val_loss: 1.3484 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 70/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6562 - loss: 0.8357 - val_accuracy: 0.5634 - val_loss: 1.3849 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 71/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6562 - loss: 0.8357 - val_accuracy: 0.5634 - val_loss: 1.3849 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 71/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.7100 - loss: 0.8103 - val_accuracy: 0.5670 - val_loss: 1.5578 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 72/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.7100 - loss: 0.8103 - val_accuracy: 0.5670 - val_loss: 1.5578 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 72/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7500 - loss: 0.8029 - val_accuracy: 0.5670 - val_loss: 1.5583 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 73/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7500 - loss: 0.8029 - val_accuracy: 0.5670 - val_loss: 1.5583 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 73/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.7180 - loss: 0.7967 - val_accuracy: 0.5413 - val_loss: 1.2943 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 74/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.7180 - loss: 0.7967 - val_accuracy: 0.5413 - val_loss: 1.2943 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 74/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6562 - loss: 0.7409 - val_accuracy: 0.5262 - val_loss: 1.3359 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 75/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6562 - loss: 0.7409 - val_accuracy: 0.5262 - val_loss: 1.3359 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 75/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.7142 - loss: 0.7871 - val_accuracy: 0.5475 - val_loss: 1.6848 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 76/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.7142 - loss: 0.7871 - val_accuracy: 0.5475 - val_loss: 1.6848 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 76/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7812 - loss: 0.6758 - val_accuracy: 0.5430 - val_loss: 1.7078 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 77/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7812 - loss: 0.6758 - val_accuracy: 0.5430 - val_loss: 1.7078 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 77/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.7174 - loss: 0.7783 - val_accuracy: 0.5989 - val_loss: 1.2690 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 78/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.7174 - loss: 0.7783 - val_accuracy: 0.5989 - val_loss: 1.2690 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 78/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6250 - loss: 0.8042 - val_accuracy: 0.5989 - val_loss: 1.2443 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 79/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6250 - loss: 0.8042 - val_accuracy: 0.5989 - val_loss: 1.2443 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 79/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.7169 - loss: 0.7757 - val_accuracy: 0.5776 - val_loss: 1.4216 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 80/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.7169 - loss: 0.7757 - val_accuracy: 0.5776 - val_loss: 1.4216 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 80/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7188 - loss: 0.7520 - val_accuracy: 0.5821 - val_loss: 1.3827 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 81/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7188 - loss: 0.7520 - val_accuracy: 0.5821 - val_loss: 1.3827 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 81/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.7270 - loss: 0.7786 - val_accuracy: 0.6096 - val_loss: 1.1868 - learning_rate: 0.0010
# Learning rate:  0.0001
# Epoch 82/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.7270 - loss: 0.7786 - val_accuracy: 0.6096 - val_loss: 1.1868 - learning_rate: 0.0010
# Learning rate:  0.0001
# Epoch 82/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6875 - loss: 0.9653 - val_accuracy: 0.6096 - val_loss: 1.1850 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 83/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6875 - loss: 0.9653 - val_accuracy: 0.6096 - val_loss: 1.1850 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 83/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.7442 - loss: 0.7315 - val_accuracy: 0.6415 - val_loss: 1.0822 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 84/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.7442 - loss: 0.7315 - val_accuracy: 0.6415 - val_loss: 1.0822 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 84/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8438 - loss: 0.5654 - val_accuracy: 0.6415 - val_loss: 1.0823 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 85/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8438 - loss: 0.5654 - val_accuracy: 0.6415 - val_loss: 1.0823 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 85/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.7545 - loss: 0.7001 - val_accuracy: 0.6424 - val_loss: 1.1095 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 86/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.7545 - loss: 0.7001 - val_accuracy: 0.6424 - val_loss: 1.1095 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 86/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7812 - loss: 0.7484 - val_accuracy: 0.6424 - val_loss: 1.1107 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 87/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7812 - loss: 0.7484 - val_accuracy: 0.6424 - val_loss: 1.1107 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 87/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 12s 84ms/step - accuracy: 0.7542 - loss: 0.6937 - val_accuracy: 0.6362 - val_loss: 1.1488 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 88/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 12s 84ms/step - accuracy: 0.7542 - loss: 0.6937 - val_accuracy: 0.6362 - val_loss: 1.1488 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 88/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8125 - loss: 0.5841 - val_accuracy: 0.6362 - val_loss: 1.1532 - learning_rate: 3.1623e-05
# Learning rate:  0.0001
# Epoch 89/200
# ...
# Learning rate:  1e-05
# Epoch 157/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - accuracy: 0.7748 - loss: 0.6392 - val_accuracy: 0.6167 - val_loss: 1.3244 - learning_rate: 1.0000e-05
# Learning rate:  1e-05
# Epoch 158/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - accuracy: 0.7748 - loss: 0.6392 - val_accuracy: 0.6167 - val_loss: 1.3244 - learning_rate: 1.0000e-05
# Learning rate:  1e-05
# Epoch 158/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8750 - loss: 0.4676 - val_accuracy: 0.6167 - val_loss: 1.3251 - learning_rate: 3.1623e-06
# Learning rate:  1e-05
# Epoch 159/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8750 - loss: 0.4676 - val_accuracy: 0.6167 - val_loss: 1.3251 - learning_rate: 3.1623e-06
# Learning rate:  1e-05
# Epoch 159/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - accuracy: 0.7690 - loss: 0.6437 - val_accuracy: 0.6122 - val_loss: 1.3089 - learning_rate: 1.0000e-05
# Learning rate:  1e-05
# Epoch 160/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - accuracy: 0.7690 - loss: 0.6437 - val_accuracy: 0.6122 - val_loss: 1.3089 - learning_rate: 1.0000e-05
# Learning rate:  1e-05
# Epoch 160/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6562 - loss: 0.7563 - val_accuracy: 0.6122 - val_loss: 1.3080 - learning_rate: 1.0000e-05
# Learning rate:  1e-05
# Epoch 161/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6562 - loss: 0.7563 - val_accuracy: 0.6122 - val_loss: 1.3080 - learning_rate: 1.0000e-05
# Learning rate:  1e-05
# Epoch 161/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - accuracy: 0.7755 - loss: 0.6355 - val_accuracy: 0.6114 - val_loss: 1.3160 - learning_rate: 1.0000e-05
# Learning rate:  1e-06
# Epoch 162/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - accuracy: 0.7755 - loss: 0.6355 - val_accuracy: 0.6114 - val_loss: 1.3160 - learning_rate: 1.0000e-05
# Learning rate:  1e-06
# Epoch 162/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8438 - loss: 0.5271 - val_accuracy: 0.6114 - val_loss: 1.3138 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 163/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8438 - loss: 0.5271 - val_accuracy: 0.6114 - val_loss: 1.3138 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 163/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - accuracy: 0.7636 - loss: 0.6418 - val_accuracy: 0.6114 - val_loss: 1.3129 - learning_rate: 5.0000e-07
# Learning rate:  1e-06
# Epoch 164/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - accuracy: 0.7636 - loss: 0.6418 - val_accuracy: 0.6114 - val_loss: 1.3129 - learning_rate: 5.0000e-07
# Learning rate:  1e-06
# Epoch 164/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8125 - loss: 0.5409 - val_accuracy: 0.6122 - val_loss: 1.3098 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 165/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8125 - loss: 0.5409 - val_accuracy: 0.6122 - val_loss: 1.3098 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 165/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 81ms/step - accuracy: 0.7692 - loss: 0.6388 - val_accuracy: 0.6122 - val_loss: 1.3119 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 166/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 81ms/step - accuracy: 0.7692 - loss: 0.6388 - val_accuracy: 0.6122 - val_loss: 1.3119 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 166/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7188 - loss: 0.7548 - val_accuracy: 0.6122 - val_loss: 1.3126 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 167/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7188 - loss: 0.7548 - val_accuracy: 0.6122 - val_loss: 1.3126 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 167/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - accuracy: 0.7706 - loss: 0.6383 - val_accuracy: 0.6105 - val_loss: 1.3205 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 168/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - accuracy: 0.7706 - loss: 0.6383 - val_accuracy: 0.6105 - val_loss: 1.3205 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 168/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7500 - loss: 0.7417 - val_accuracy: 0.6158 - val_loss: 1.3206 - learning_rate: 5.0000e-07
# Learning rate:  1e-06
# Epoch 169/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7500 - loss: 0.7417 - val_accuracy: 0.6158 - val_loss: 1.3206 - learning_rate: 5.0000e-07
# Learning rate:  1e-06
# Epoch 169/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 77ms/step - accuracy: 0.7764 - loss: 0.6326 - val_accuracy: 0.6114 - val_loss: 1.3188 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 170/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 77ms/step - accuracy: 0.7764 - loss: 0.6326 - val_accuracy: 0.6114 - val_loss: 1.3188 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 170/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7812 - loss: 0.6974 - val_accuracy: 0.6114 - val_loss: 1.3187 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 171/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7812 - loss: 0.6974 - val_accuracy: 0.6114 - val_loss: 1.3187 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 171/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step - accuracy: 0.7762 - loss: 0.6374 - val_accuracy: 0.6114 - val_loss: 1.3166 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 172/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step - accuracy: 0.7762 - loss: 0.6374 - val_accuracy: 0.6114 - val_loss: 1.3166 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 172/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8125 - loss: 0.6365 - val_accuracy: 0.6114 - val_loss: 1.3165 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 173/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8125 - loss: 0.6365 - val_accuracy: 0.6114 - val_loss: 1.3165 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 173/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - accuracy: 0.7706 - loss: 0.6372 - val_accuracy: 0.6122 - val_loss: 1.3152 - learning_rate: 5.0000e-07
# Learning rate:  1e-06
# Epoch 174/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - accuracy: 0.7706 - loss: 0.6372 - val_accuracy: 0.6122 - val_loss: 1.3152 - learning_rate: 5.0000e-07
# Learning rate:  1e-06
# Epoch 174/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7188 - loss: 0.7289 - val_accuracy: 0.6131 - val_loss: 1.3169 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 175/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7188 - loss: 0.7289 - val_accuracy: 0.6131 - val_loss: 1.3169 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 175/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - accuracy: 0.7730 - loss: 0.6347 - val_accuracy: 0.6122 - val_loss: 1.3179 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 176/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - accuracy: 0.7730 - loss: 0.6347 - val_accuracy: 0.6122 - val_loss: 1.3179 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 176/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8125 - loss: 0.5908 - val_accuracy: 0.6122 - val_loss: 1.3179 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 177/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8125 - loss: 0.5908 - val_accuracy: 0.6122 - val_loss: 1.3179 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 177/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - accuracy: 0.7753 - loss: 0.6384 - val_accuracy: 0.6131 - val_loss: 1.3160 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 178/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - accuracy: 0.7753 - loss: 0.6384 - val_accuracy: 0.6131 - val_loss: 1.3160 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 178/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9375 - loss: 0.4330 - val_accuracy: 0.6149 - val_loss: 1.3127 - learning_rate: 5.0000e-07
# Learning rate:  1e-06
# Epoch 179/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9375 - loss: 0.4330 - val_accuracy: 0.6149 - val_loss: 1.3127 - learning_rate: 5.0000e-07
# Learning rate:  1e-06
# Epoch 179/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - accuracy: 0.7757 - loss: 0.6319 - val_accuracy: 0.6131 - val_loss: 1.3131 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 180/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - accuracy: 0.7757 - loss: 0.6319 - val_accuracy: 0.6131 - val_loss: 1.3131 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 180/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6562 - loss: 0.7745 - val_accuracy: 0.6131 - val_loss: 1.3115 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 181/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6562 - loss: 0.7745 - val_accuracy: 0.6131 - val_loss: 1.3115 - learning_rate: 1.0000e-06
# Learning rate:  1e-06
# Epoch 181/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 12s 87ms/step - accuracy: 0.7764 - loss: 0.6283 - val_accuracy: 0.6114 - val_loss: 1.3247 - learning_rate: 1.0000e-06
# Learning rate:  5e-07
# Epoch 182/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 12s 87ms/step - accuracy: 0.7764 - loss: 0.6283 - val_accuracy: 0.6114 - val_loss: 1.3247 - learning_rate: 1.0000e-06
# Learning rate:  5e-07
# Epoch 182/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8125 - loss: 0.5374 - val_accuracy: 0.6114 - val_loss: 1.3238 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 183/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8125 - loss: 0.5374 - val_accuracy: 0.6114 - val_loss: 1.3238 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 183/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - accuracy: 0.7771 - loss: 0.6383 - val_accuracy: 0.6122 - val_loss: 1.3130 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 184/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - accuracy: 0.7771 - loss: 0.6383 - val_accuracy: 0.6122 - val_loss: 1.3130 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 184/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7812 - loss: 0.5501 - val_accuracy: 0.6122 - val_loss: 1.3145 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 185/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7812 - loss: 0.5501 - val_accuracy: 0.6122 - val_loss: 1.3145 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 185/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 75ms/step - accuracy: 0.7733 - loss: 0.6334 - val_accuracy: 0.6114 - val_loss: 1.3201 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 186/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 75ms/step - accuracy: 0.7733 - loss: 0.6334 - val_accuracy: 0.6114 - val_loss: 1.3201 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 186/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6875 - loss: 0.8755 - val_accuracy: 0.6114 - val_loss: 1.3227 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 187/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6875 - loss: 0.8755 - val_accuracy: 0.6114 - val_loss: 1.3227 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 187/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - accuracy: 0.7686 - loss: 0.6435 - val_accuracy: 0.6122 - val_loss: 1.3272 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 188/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - accuracy: 0.7686 - loss: 0.6435 - val_accuracy: 0.6122 - val_loss: 1.3272 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 188/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7500 - loss: 0.7025 - val_accuracy: 0.6114 - val_loss: 1.3300 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 189/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7500 - loss: 0.7025 - val_accuracy: 0.6114 - val_loss: 1.3300 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 189/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - accuracy: 0.7764 - loss: 0.6339 - val_accuracy: 0.6122 - val_loss: 1.3141 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 190/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - accuracy: 0.7764 - loss: 0.6339 - val_accuracy: 0.6122 - val_loss: 1.3141 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 190/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7188 - loss: 0.6585 - val_accuracy: 0.6114 - val_loss: 1.3151 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 191/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7188 - loss: 0.6585 - val_accuracy: 0.6114 - val_loss: 1.3151 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 191/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step - accuracy: 0.7719 - loss: 0.6343 - val_accuracy: 0.6114 - val_loss: 1.3238 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 192/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step - accuracy: 0.7719 - loss: 0.6343 - val_accuracy: 0.6114 - val_loss: 1.3238 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 192/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7812 - loss: 0.5845 - val_accuracy: 0.6114 - val_loss: 1.3195 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 193/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7812 - loss: 0.5845 - val_accuracy: 0.6114 - val_loss: 1.3195 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 193/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - accuracy: 0.7728 - loss: 0.6343 - val_accuracy: 0.6122 - val_loss: 1.3158 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 194/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - accuracy: 0.7728 - loss: 0.6343 - val_accuracy: 0.6122 - val_loss: 1.3158 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 194/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7188 - loss: 0.6220 - val_accuracy: 0.6122 - val_loss: 1.3160 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 195/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7188 - loss: 0.6220 - val_accuracy: 0.6122 - val_loss: 1.3160 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 195/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step - accuracy: 0.7762 - loss: 0.6362 - val_accuracy: 0.6114 - val_loss: 1.3252 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 196/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step - accuracy: 0.7762 - loss: 0.6362 - val_accuracy: 0.6114 - val_loss: 1.3252 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 196/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8750 - loss: 0.5125 - val_accuracy: 0.6122 - val_loss: 1.3232 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 197/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8750 - loss: 0.5125 - val_accuracy: 0.6122 - val_loss: 1.3232 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 197/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - accuracy: 0.7728 - loss: 0.6337 - val_accuracy: 0.6122 - val_loss: 1.3286 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 198/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - accuracy: 0.7728 - loss: 0.6337 - val_accuracy: 0.6122 - val_loss: 1.3286 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 198/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8125 - loss: 0.6648 - val_accuracy: 0.6122 - val_loss: 1.3285 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 199/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8125 - loss: 0.6648 - val_accuracy: 0.6122 - val_loss: 1.3285 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 199/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - accuracy: 0.7724 - loss: 0.6348 - val_accuracy: 0.6122 - val_loss: 1.3188 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 200/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - accuracy: 0.7724 - loss: 0.6348 - val_accuracy: 0.6122 - val_loss: 1.3188 - learning_rate: 5.0000e-07
# Learning rate:  5e-07
# Epoch 200/200
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8750 - loss: 0.5854 - val_accuracy: 0.6122 - val_loss: 1.3194 - learning_rate: 5.0000e-07
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8750 - loss: 0.5854 - val_accuracy: 0.6122 - val_loss: 1.3194 - learning_rate: 5.0000e-07
